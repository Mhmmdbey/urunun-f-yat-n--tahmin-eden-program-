# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv(r'C:\Users\muham\Desktop\makine öğrenmesi proje\veri_düzenleme.csv')

# %%
df=pd.DataFrame()

# %%
data.head(600)
# Out:
#      Arka_Kamera_Sayisi Cep_Telefonu_Modeli Dahili_Hafiza Dokunmatik_Ekran  \
# 0                   3.0  Reeder S19 Max Pro          128               Var
# 1                   3.0                 NaN          128               Var
# 2                   NaN                 NaN           NaN              NaN
# 3                   NaN                 NaN           NaN              NaN
# 4                   NaN                 NaN           NaN              NaN
# ..                  ...                 ...           ...              ...
# 595                 4.0      Xiaomi 11T Pro          256               Var
# 596                 3.0       Redmi Note 11           64               Var
# 597                 4.0                 NaN          128               Var
# 598                 1.0      Huawei Y6 2019           32               Var
# 599                 NaN                 NaN           NaN              Var
#
# ...

# %%
df['Fiyat']=data['Fiyat']
df['Dokunmatik_Ekran']=data['Dokunmatik_Ekran']
df['Suya_Toza_Dayanıklılık']=data['Suya_Toza_Dayanıklılık']
df['Çift_Hat']=data['Çift_Hat']
df['Ön_Kamera_Sayısı']=data['Ön_Kamera_Sayısı']
df['İşletim_Sistemi']=data['İşletim_Sistemi']
df['Arka_Kamera_Sayisi']=data['Arka_Kamera_Sayisi']
df['Cep_Telefonu_Modeli']=data['Cep_Telefonu_Modeli']
df['Dahili_Hafiza']=data['Dahili_Hafiza']
df['Garanti_Süresi']=data['Garanti_Süresi']
df['NFC']=data['NFC']
df['RAM_Kapasitesi']=data['RAM_Kapasitesi']
df['Renk']=data['Renk']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      421 non-null    float64
#  1   Cep_Telefonu_Modeli     235 non-null    object
#  2   Dahili_Hafiza           421 non-null    object
#  3   Dokunmatik_Ekran        459 non-null    object
#  4   Garanti_Süresi          421 non-null    float64
#  5   NFC                     459 non-null    object
#  6   RAM_Kapasitesi          459 non-null    object
#  7   Renk                    459 non-null    object
#  8   Suya_Toza_Dayanıklılık  421 non-null    object
#  9   Çift_Hat                421 non-null    object
#  10  Ön_Kamera_Sayısı        421 non-null    float64
#  11  İşletim_Sistemi         421 non-null    object
#  12  Fiyat                   600 non-null    float64
# dtypes: float64(4), object(9)
# memory usage: 61.1+ KB

# %%
# Sayısal kısmı alarak sütunu temizleyin
data['Dahili_Hafiza'] = data['Dahili_Hafiza'].str.extract('(\d+)').astype(float)

# '1 TB' gibi değerleri uygun bir şekilde ele alarak dönüştürün
# Örneğin, 1 TB'yi 1000 GB olarak düşünebilirsiniz (opsiyonel)
data.loc[data['Dahili_Hafiza'].notnull(), 'Dahili_Hafiza'] *= 1000

# %%
import pandas as pd

# Veriyi yükleyin (eğer daha önce yüklemediyseniz)
# data = pd.read_csv('telefonverisi_data.csv')

# 'RAM_Kapasitesi' sütunundaki '32 +' gibi değerleri kontrol edin
invalid_values = data[data['RAM_Kapasitesi'].str.contains('\+', na=False)]
print("Geçersiz Değerler:")
print(invalid_values['RAM_Kapasitesi'])

# Sayısal kısmı alarak sütunu temizleyin
data['RAM_Kapasitesi'] = data['RAM_Kapasitesi'].str.extract('(\d+)').astype(float)

# Veriyi inceleyin
data.info()
# Out:
# Geçersiz Değerler:
# 390    32  +
# Name: RAM_Kapasitesi, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      421 non-null    float64
#  1   Cep_Telefonu_Modeli     235 non-null    object
#  2   Dahili_Hafiza           421 non-null    float64
#  3   Dokunmatik_Ekran        459 non-null    object
#  4   Garanti_Süresi          421 non-null    float64
#  5   NFC                     459 non-null    object
#  6   RAM_Kapasitesi          459 non-null    float64
#  7   Renk                    459 non-null    object
#  8   Suya_Toza_Dayanıklılık  421 non-null    object
#  9   Çift_Hat                421 non-null    object
#  10  Ön_Kamera_Sayısı        421 non-null    float64
#  11  İşletim_Sistemi         421 non-null    object
#  12  Fiyat                   600 non-null    float64
# ...

# %%
import pandas as pd

# Örnek olarak bir DataFrame oluşturun veya veri setinizi yükleyin
# Örneğin:
# df = pd.DataFrame({'Column1': [1, 2, 3, None, 5], 'Column2': [None, 7, 8, 9, 10]})

# DataFrame'inizdeki NaN değerlerin sayısını görüntüleyin
nan_count = df.isnull().sum().sum()

# Her sütun için NaN değerlerin sayısını görmek istiyorsanız:
# nan_count_per_column = df.isnull().sum()

# Sonucu yazdırın
print(f"Toplam NaN değer sayısı: {nan_count}")
# print("Her sütun için NaN değer sayısı:")
# print(nan_count_per_column)
# Out:
# Toplam NaN değer sayısı: 2182

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      421 non-null    float64
#  1   Cep_Telefonu_Modeli     235 non-null    object
#  2   Dahili_Hafiza           421 non-null    float64
#  3   Dokunmatik_Ekran        459 non-null    object
#  4   Garanti_Süresi          421 non-null    float64
#  5   NFC                     459 non-null    object
#  6   RAM_Kapasitesi          459 non-null    float64
#  7   Renk                    459 non-null    object
#  8   Suya_Toza_Dayanıklılık  421 non-null    object
#  9   Çift_Hat                421 non-null    object
#  10  Ön_Kamera_Sayısı        421 non-null    float64
#  11  İşletim_Sistemi         421 non-null    object
#  12  Fiyat                   600 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 61.1+ KB

# %%
most_common_value = data['Arka_Kamera_Sayisi'].mode()[0]
data['Arka_Kamera_Sayisi'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Dokunmatik_Ekran'].mode()[0]
data['Dokunmatik_Ekran'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['NFC'].mode()[0]
data['NFC'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Cep_Telefonu_Modeli'].mode()[0]
data['Cep_Telefonu_Modeli'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Renk'].mode()[0]
data['Renk'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Suya_Toza_Dayanıklılık'].mode()[0]
data['Suya_Toza_Dayanıklılık'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Çift_Hat'].mode()[0]
data['Çift_Hat'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['İşletim_Sistemi'].mode()[0]
data['İşletim_Sistemi'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Dahili_Hafiza'].mode()[0]
data['Dahili_Hafiza'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Garanti_Süresi'].mode()[0]
data['Garanti_Süresi'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['RAM_Kapasitesi'].mode()[0]
data['RAM_Kapasitesi'].fillna(most_common_value, inplace=True)

# %%
most_common_value = data['Ön_Kamera_Sayısı'].mode()[0]
data['Ön_Kamera_Sayısı'].fillna(most_common_value, inplace=True)

# %%
data.tail(50)
# Out:
#      Arka_Kamera_Sayisi Cep_Telefonu_Modeli  Dahili_Hafiza Dokunmatik_Ekran  \
# 550                 3.0           iPhone 12       128000.0              Var
# 551                 3.0       iPhone 15 Pro       512000.0              Var
# 552                 4.0          Reno5 Lite       128000.0              Var
# 553                 2.0           iPhone 15       128000.0              Var
# 554                 4.0          Galaxy M33       128000.0              Var
# 555                 3.0           iPhone 12       128000.0              Var
# 556                 3.0           iPhone 12       128000.0              Var
# 557                 2.0          Galaxy A04        64000.0              Var
# 558                 3.0           iPhone 12       128000.0              Var
# 559                 4.0         Galaxy M31s       128000.0              Var
# 560                 3.0           iPhone 12       128000.0              Var
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      600 non-null    float64
#  1   Cep_Telefonu_Modeli     600 non-null    object
#  2   Dahili_Hafiza           600 non-null    float64
#  3   Dokunmatik_Ekran        600 non-null    object
#  4   Garanti_Süresi          600 non-null    float64
#  5   NFC                     600 non-null    object
#  6   RAM_Kapasitesi          600 non-null    float64
#  7   Renk                    600 non-null    object
#  8   Suya_Toza_Dayanıklılık  600 non-null    object
#  9   Çift_Hat                600 non-null    object
#  10  Ön_Kamera_Sayısı        600 non-null    float64
#  11  İşletim_Sistemi         600 non-null    object
#  12  Fiyat                   600 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 61.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder
enc= LabelEncoder()

# %%
data['Cep_Telefonu_Modeli']=enc.fit_transform(data['Cep_Telefonu_Modeli'])

# %%
data['Cep_Telefonu_Modeli'].value_counts()
# Out:
# Cep_Telefonu_Modeli
# 71    376
# 85     10
# 83     10
# 82      9
# 79      6
#      ...
# 76      1
# 5       1
# 55      1
# 40      1
# 28      1
# Name: count, Length: 87, dtype: int64

# %%
data['Renk']=enc.fit_transform(data['Renk'])

# %%
data['Renk'].value_counts()
# Out:
# Renk
# 18    274
# 12     85
# 3      52
# 21     38
# 5      34
# 14     27
# 22     18
# 7      12
# 1      10
# 15     10
# 17     10
# 2       8
# 10      5
# 0       4
# 6       2
# 9       2
# 4       2
# 8       2
# 11      1
# 13      1
# 19      1
# 20      1
# 16      1
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      600 non-null    float64
#  1   Cep_Telefonu_Modeli     600 non-null    int32
#  2   Dahili_Hafiza           600 non-null    float64
#  3   Dokunmatik_Ekran        600 non-null    object
#  4   Garanti_Süresi          600 non-null    float64
#  5   NFC                     600 non-null    object
#  6   RAM_Kapasitesi          600 non-null    float64
#  7   Renk                    600 non-null    int32
#  8   Suya_Toza_Dayanıklılık  600 non-null    object
#  9   Çift_Hat                600 non-null    object
#  10  Ön_Kamera_Sayısı        600 non-null    float64
#  11  İşletim_Sistemi         600 non-null    object
#  12  Fiyat                   600 non-null    float64
# dtypes: float64(6), int32(2), object(5)
# memory usage: 56.4+ KB

# %%
data.head(60)
# Out:
#     Arka_Kamera_Sayisi  Cep_Telefonu_Modeli  Dahili_Hafiza Dokunmatik_Ekran  \
# 0                  3.0                   61       128000.0              Var
# 1                  3.0                   71       128000.0              Var
# 2                  3.0                   71       128000.0              Var
# 3                  3.0                   71       128000.0              Var
# 4                  3.0                   71       128000.0              Var
# 5                  3.0                   71       128000.0              Var
# 6                  2.0                   71       128000.0              Var
# 7                  3.0                   54       128000.0              Var
# 8                  3.0                   61       128000.0              Var
# 9                  3.0                   71        64000.0              Var
# 10                 3.0                    9       128000.0              Var
# ...

# %%
data["İşletim_Sistemi"]=data["İşletim_Sistemi"].replace(['iOS'],'1')
data["İşletim_Sistemi"]=data["İşletim_Sistemi"].replace(['Android'],'0')
data["Dokunmatik_Ekran"]=data["Dokunmatik_Ekran"].replace(['Var'],'1')
data["Dokunmatik_Ekran"]=data["Dokunmatik_Ekran"].replace(['Yok'],'0')
data["NFC"]=data["NFC"].replace(['Var'],'1')
data["NFC"]=data["NFC"].replace(['Yok'],'0')
data["Suya_Toza_Dayanıklılık"]=data["Suya_Toza_Dayanıklılık"].replace(['Var'],'1')
data["Suya_Toza_Dayanıklılık"]=data["Suya_Toza_Dayanıklılık"].replace(['Yok'],'0')
data["NFC"]=data["NFC"].replace(['Var'],'1')
data["NFC"]=data["NFC"].replace(['Yok'],'0')
data["Çift_Hat"]=data["Çift_Hat"].replace(['Var'],'1')
data["Çift_Hat"]=data["Çift_Hat"].replace(['Yok'],'0')

# %%
import pandas as pd

# Veriyi yükleyin (eğer daha önce yüklemediyseniz)
# data = pd.read_csv('telefonverisi_data.csv')

# 'RAM_Kapasitesi' sütunundaki '32 +' gibi değerleri kontrol edin
invalid_values = data[data['İşletim_Sistemi'].str.contains('\+', na=False)]
print("Geçersiz Değerler:")
print(invalid_values['İşletim_Sistemi'])

# Sayısal kısmı alarak sütunu temizleyin
data['İşletim_Sistemi'] = data['İşletim_Sistemi'].str.extract('(\d+)').astype(float)

# Veriyi inceleyin
data.info()
# Out:
# Geçersiz Değerler:
# Series([], Name: İşletim_Sistemi, dtype: object)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      600 non-null    float64
#  1   Cep_Telefonu_Modeli     600 non-null    int32
#  2   Dahili_Hafiza           600 non-null    float64
#  3   Dokunmatik_Ekran        600 non-null    object
#  4   Garanti_Süresi          600 non-null    float64
#  5   NFC                     600 non-null    object
#  6   RAM_Kapasitesi          600 non-null    float64
#  7   Renk                    600 non-null    int32
#  8   Suya_Toza_Dayanıklılık  600 non-null    object
#  9   Çift_Hat                600 non-null    object
#  10  Ön_Kamera_Sayısı        600 non-null    float64
#  11  İşletim_Sistemi         599 non-null    float64
#  12  Fiyat                   600 non-null    float64
# ...

# %%
data.head(250)
# Out:
#      Arka_Kamera_Sayisi  Cep_Telefonu_Modeli  Dahili_Hafiza Dokunmatik_Ekran  \
# 0                   3.0                   61       128000.0                1
# 1                   3.0                   71       128000.0                1
# 2                   3.0                   71       128000.0                1
# 3                   3.0                   71       128000.0                1
# 4                   3.0                   71       128000.0                1
# ..                  ...                  ...            ...              ...
# 245                 4.0                   50       128000.0                1
# 246                 2.0                   71       128000.0                1
# 247                 2.0                   78       128000.0                1
# 248                 2.0                   71       128000.0                1
# 249                 3.0                    2       128000.0                1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arka_Kamera_Sayisi      600 non-null    float64
#  1   Cep_Telefonu_Modeli     600 non-null    int32
#  2   Dahili_Hafiza           600 non-null    float64
#  3   Dokunmatik_Ekran        600 non-null    object
#  4   Garanti_Süresi          600 non-null    float64
#  5   NFC                     600 non-null    object
#  6   RAM_Kapasitesi          600 non-null    float64
#  7   Renk                    600 non-null    int32
#  8   Suya_Toza_Dayanıklılık  600 non-null    object
#  9   Çift_Hat                600 non-null    object
#  10  Ön_Kamera_Sayısı        600 non-null    float64
#  11  İşletim_Sistemi         599 non-null    float64
#  12  Fiyat                   600 non-null    float64
# dtypes: float64(7), int32(2), object(4)
# memory usage: 56.4+ KB

# %%
print(df['Renk'].isnull().values.any())
print(df['Arka_Kamera_Sayisi'].isnull().values.any())
print(df['Garanti_Süresi'].isnull().values.any())
print(df['RAM_Kapasitesi'].isnull().values.any())
print(df['Dahili_Hafiza'].isnull().values.any())
print(df['Dokunmatik_Ekran'].isnull().values.any())
print(df['NFC'].isnull().values.any())
print(df['Suya_Toza_Dayanıklılık'].isnull().values.any())
print(df['Çift_Hat'].isnull().values.any())
print(df['Ön_Kamera_Sayısı'].isnull().values.any())
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
print(df.columns)
# Out:
# Index(['Fiyat', 'Dokunmatik_Ekran', 'Suya_Toza_Dayanıklılık', 'Çift_Hat',
#        'Ön_Kamera_Sayısı', 'İşletim_Sistemi', 'Arka_Kamera_Sayisi',
#        'Cep_Telefonu_Modeli', 'Dahili_Hafiza', 'Garanti_Süresi', 'NFC',
#        'RAM_Kapasitesi', 'Renk'],
#       dtype='object')

# %%
data.tail(50)
# Out:
#      Arka_Kamera_Sayisi  Cep_Telefonu_Modeli  Dahili_Hafiza Dokunmatik_Ekran  \
# 550                 3.0                   71       128000.0                1
# 551                 3.0                   84       512000.0                1
# 552                 4.0                   62       128000.0                1
# 553                 2.0                   82       128000.0                1
# 554                 4.0                   17       128000.0                1
# 555                 3.0                   71       128000.0                1
# 556                 3.0                   71       128000.0                1
# 557                 2.0                    1        64000.0                1
# 558                 3.0                   71       128000.0                1
# 559                 4.0                   16       128000.0                1
# 560                 3.0                   71       128000.0                1
# ...

# %%
data.to_csv(r'C:\Users\muham\Desktop\makine öğrenmesi proje\veri_algoritma_yeni.csv', index=False)
